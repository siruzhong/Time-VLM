# %%
# 数据定义
data_input_length = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'seq_len': [96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024],
    'Avg': [0.440, 0.428, 0.415, 0.413, 0.418, 0.419,
            0.386, 0.373, 0.351, 0.347, 0.348, 0.342,
            0.421, 0.416, 0.360, 0.357, 0.355, 0.354,
            0.328, 0.296, 0.262, 0.260, 0.258, 0.250,
            0.268, 0.258, 0.248, 0.244, 0.242, 0.238,
            0.223, 0.192, 0.178, 0.174, 0.172, 0.165,
            0.628, 0.484, 0.441, 0.426, 0.419, 0.405]
}

data_norm_const = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'norm_const': [0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1],
    'Avg': [0.420, 0.413, 0.415, 0.418,
            0.355, 0.347, 0.350, 0.353,
            0.365, 0.357, 0.360, 0.363,
            0.268, 0.260, 0.263, 0.266,
            0.252, 0.244, 0.247, 0.250,
            0.182, 0.174, 0.177, 0.175,
            0.437, 0.426, 0.430, 0.427]
}

data_d_model = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'd_model': [32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512],
    'Avg': [0.421, 0.415, 0.413, 0.414, 0.415,
            0.359, 0.350, 0.347, 0.348, 0.349,
            0.363, 0.355, 0.357, 0.358, 0.359,
            0.271, 0.265, 0.260, 0.261, 0.262,
            0.256, 0.250, 0.244, 0.245, 0.246,
            0.187, 0.180, 0.174, 0.175, 0.176,
            0.439, 0.430, 0.426, 0.427, 0.428]
}

data_pred_hidden_len = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'd_model': [32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512,
                32, 64, 128, 256, 512],
    'Avg': [0.423, 0.420, 0.413, 0.415, 0.414,
            0.357, 0.355, 0.347, 0.348, 0.347,
            0.368, 0.365, 0.357, 0.254, 0.253,
            0.268, 0.265, 0.260, 0.256, 0.255,
            0.251, 0.248, 0.244, 0.238, 0.237,
            0.179, 0.177, 0.174, 0.171, 0.170,
            0.439, 0.435, 0.426, 0.421, 0.420]
}

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 设置全局字体为 Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# 转换为DataFrame
df_input_length = pd.DataFrame(data_input_length)
df_norm_const = pd.DataFrame(data_norm_const)
df_d_model = pd.DataFrame(data_d_model)
df_pred_hidden_len = pd.DataFrame(data_pred_hidden_len)

# 使用 seaborn 的调色板生成 7 种颜色
colors = sns.color_palette('husl', n_colors=7)  # 使用 'husl' 调色板生成 7 种颜色

# 创建画布和子图
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(24, 6), dpi=300)

# 绘制第一个子图：Input Length
ax1 = axes[0]
for i, (dataset, group) in enumerate(df_input_length.groupby('Dataset')):
    ax1.plot(group['seq_len'], group['Avg'], label=dataset, linestyle='-', linewidth=2, marker='o', markersize=5, color=colors[i])
ax1.set_title('(a) Analysis on Input Length', loc='center', pad=20, fontsize=20, fontweight='bold')
ax1.set_xlabel('Input Length (seq_len)', fontsize=18)
ax1.set_ylabel('MAE', fontsize=18)
ax1.grid(True, linestyle='--', alpha=0.7)
ax1.legend(loc='upper right', fontsize=12)

# 绘制第二个子图：Normalization Constant
ax2 = axes[1]
for i, (dataset, group) in enumerate(df_norm_const.groupby('Dataset')):
    ax2.plot(group['norm_const'], group['Avg'], label=dataset, linestyle='-', linewidth=2, marker='o', markersize=5, color=colors[i])
ax2.set_title('(b) Analysis on Normalization Constant', loc='center', pad=20, fontsize=20, fontweight='bold')
ax2.set_xlabel('Normalization Constant (norm_const)', fontsize=18)
ax2.set_ylabel('MAE', fontsize=18)
ax2.grid(True, linestyle='--', alpha=0.7)

# 绘制第三个子图：Dimension of Model
ax3 = axes[2]
for i, (dataset, group) in enumerate(df_d_model.groupby('Dataset')):
    ax3.plot(group['d_model'], group['Avg'], label=dataset, linestyle='-', linewidth=2, marker='o', markersize=5, color=colors[i])
ax3.set_title('(c) Analysis on Dimension of Model', loc='center', pad=20, fontsize=20, fontweight='bold')
ax3.set_xlabel('Dimension of Model (d_model)', fontsize=18)
ax3.set_ylabel('MAE', fontsize=18)
ax3.grid(True, linestyle='--', alpha=0.7)

# 绘制第四个子图：Predictor Hidden Length
ax4 = axes[3]
for i, (dataset, group) in enumerate(df_pred_hidden_len.groupby('Dataset')):
    ax4.plot(group['d_model'], group['Avg'], label=dataset, linestyle='-', linewidth=2, marker='o', markersize=5, color=colors[i])
ax4.set_title('(d) Analysis on Predictor Hidden Length', loc='center', pad=20, fontsize=20, fontweight='bold')
ax4.set_xlabel('Predictor Hidden Length (pred_hidden_len)', fontsize=18)
ax4.set_ylabel('MAE', fontsize=18)
ax4.grid(True, linestyle='--', alpha=0.7)

# 调整布局
plt.tight_layout()

# 保存图像
plt.savefig('timevlm_hyperparameter_analysis.png', dpi=300, bbox_inches='tight')

# 显示图像
plt.show()
