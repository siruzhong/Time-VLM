# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 设置全局字体为 Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12

# 数据
data = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'seq_len': [96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024],
    'Avg': [0.440, 0.428, 0.415, 0.413, 0.418, 0.419,
            0.386, 0.373, 0.351, 0.347, 0.348, 0.342,
            0.421, 0.416, 0.360, 0.357, 0.355, 0.354,
            0.328, 0.296, 0.262, 0.260, 0.258, 0.250,
            0.268, 0.258, 0.248, 0.244, 0.242, 0.238,
            0.223, 0.192, 0.178, 0.174, 0.172, 0.165,
            0.628, 0.484, 0.441, 0.426, 0.419, 0.405]
}

# 转换为DataFrame
df = pd.DataFrame(data)

# 设置seaborn风格
sns.set(style="white", palette="husl", font_scale=1.2)

# 创建折线图
plt.figure(figsize=(6, 6), dpi=300)
ax = sns.lineplot(x='seq_len', y='Avg', hue='Dataset', style='Dataset', 
                  markers=True, dashes=False, data=df, linewidth=2, markersize=8)

# 添加标题和标签
plt.title('Analysis on Input Length', fontsize=16, pad=10, fontweight='bold')
plt.xlabel('Input Length', fontsize=14, labelpad=10, fontweight='bold')
plt.ylabel('MAE', fontsize=14, labelpad=10, fontweight='bold')

# 调整图例位置到图表内部
plt.legend(title='Dataset', loc='upper right', fontsize=10, title_fontsize=12, 
           bbox_to_anchor=(1, 1), frameon=False)

# 去掉内部网格线
ax.grid(False)
ax.get_legend().remove()

# 仅保留底部和左侧坐标轴
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

# 调整x轴刻度
plt.xticks([96, 192, 336, 512, 672, 1024], fontsize=12)
plt.yticks(fontsize=12)

# 显示图像
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 设置全局字体为 Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12

# 数据
data = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'norm_c': [0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1],
    'Avg': [0.420, 0.413, 0.415, 0.418,
            0.355, 0.347, 0.350, 0.353,
            0.365, 0.357, 0.360, 0.363,
            0.268, 0.260, 0.263, 0.266,
            0.252, 0.244, 0.247, 0.250,
            0.182, 0.174, 0.177, 0.175,
            0.437, 0.426, 0.430, 0.427]
}

# 转换为DataFrame
df = pd.DataFrame(data)

# 设置seaborn风格
sns.set(style="white", palette="husl", font_scale=1.2)

# 创建折线图
plt.figure(figsize=(6, 6), dpi=300)
ax = sns.lineplot(x='norm_c', y='Avg', hue='Dataset', style='Dataset', 
                  markers=True, dashes=False, data=df, linewidth=2, markersize=8)

# 添加标题和标签
plt.title('Analysis on Input Length', fontsize=16, pad=10, fontweight='bold')
plt.xlabel('Input Length', fontsize=14, labelpad=10, fontweight='bold')
plt.ylabel('MAE', fontsize=14, labelpad=10, fontweight='bold')

# 调整图例位置到图表内部
plt.legend(title='Dataset', loc='upper right', fontsize=10, title_fontsize=12, 
           bbox_to_anchor=(1, 1), frameon=False)

# 去掉内部网格线
ax.grid(False)
ax.get_legend().remove()

# 仅保留底部和左侧坐标轴
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

# 调整x轴刻度
plt.xticks([0.1, 0.4, 0.7, 1], fontsize=12)
plt.yticks(fontsize=12)

# 显示图像
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 设置全局字体为 Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12

# 数据 1: seq_len
data_seq_len = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'seq_len': [96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024,
                96, 192, 336, 512, 672, 1024],
    'Avg': [0.440, 0.428, 0.415, 0.413, 0.418, 0.419,
            0.386, 0.373, 0.351, 0.347, 0.348, 0.342,
            0.421, 0.416, 0.360, 0.357, 0.355, 0.354,
            0.328, 0.296, 0.262, 0.260, 0.258, 0.250,
            0.268, 0.258, 0.248, 0.244, 0.242, 0.238,
            0.223, 0.192, 0.178, 0.174, 0.172, 0.165,
            0.628, 0.484, 0.441, 0.426, 0.419, 0.405]
}

# 数据 2: norm_c
data_norm_c = {
    'Dataset': ['ETTh1', 'ETTh1', 'ETTh1', 'ETTh1',
                'ETTh2', 'ETTh2', 'ETTh2', 'ETTh2',
                'ETTm1', 'ETTm1', 'ETTm1', 'ETTm1',
                'ETTm2', 'ETTm2', 'ETTm2', 'ETTm2',
                'Weather', 'Weather', 'Weather', 'Weather',
                'ECL', 'ECL', 'ECL', 'ECL',
                'Traffic', 'Traffic', 'Traffic', 'Traffic'],
    'norm_c': [0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1,
               0.1, 0.4, 0.7, 1],
    'Avg': [0.420, 0.413, 0.419, 0.418,
            0.355, 0.347, 0.352, 0.353,
            0.365, 0.357, 0.363, 0.368,
            0.268, 0.260, 0.266, 0.240,
            0.252, 0.244, 0.247, 0.250,
            0.182, 0.174, 0.180, 0.179,
            0.437, 0.426, 0.433, 0.427]
}

# 转换为DataFrame
df_seq_len = pd.DataFrame(data_seq_len)
df_norm_c = pd.DataFrame(data_norm_c)

# 设置seaborn风格
sns.set(style="white", palette="husl", font_scale=1.2)

# 创建子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6), dpi=300)

# 第一个图表：seq_len
sns.lineplot(x='seq_len', y='Avg', hue='Dataset', style='Dataset', 
             markers=True, dashes=False, data=df_seq_len, linewidth=2, markersize=8, ax=ax1)
ax1.set_title('Analysis on Input Length', fontsize=16, pad=20, fontweight='bold')
ax1.set_xlabel('Input Length', fontsize=14, labelpad=10, fontweight='bold')
ax1.set_ylabel('MAE', fontsize=14, labelpad=10, fontweight='bold')
ax1.grid(False)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_linewidth(1.5)
ax1.spines['left'].set_linewidth(1.5)
ax1.set_xticks([96, 192, 336, 512, 672, 1024])
ax1.tick_params(axis='both', labelsize=12)

# 第二个图表：norm_c
sns.lineplot(x='norm_c', y='Avg', hue='Dataset', style='Dataset', 
             markers=True, dashes=False, data=df_norm_c, linewidth=2, markersize=8, ax=ax2)
ax2.set_title('Analysis on Normalization Constant', fontsize=16, pad=20, fontweight='bold')
ax2.set_xlabel('Normalization Constant', fontsize=14, labelpad=10, fontweight='bold')
ax2.set_ylabel('MAE', fontsize=14, labelpad=10, fontweight='bold')
ax2.grid(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_linewidth(1.5)
ax2.spines['left'].set_linewidth(1.5)
ax2.set_xticks([0.1, 0.4, 0.7, 1])
ax2.tick_params(axis='both', labelsize=12)

# 共享一个图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, title='Dataset', loc='upper center', 
           bbox_to_anchor=(0.5, 1.05), ncol=7, fontsize=10, title_fontsize=12, frameon=False)

# 移除子图中的图例
ax1.get_legend().remove()
ax2.get_legend().remove()

# 调整布局
plt.tight_layout()

# 显示图像
plt.show()
